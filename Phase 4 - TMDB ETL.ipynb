# %% [markdown]
# # **Phase 4 - TMDB ETL**
#
# - Yvon Bilodeau
# - May 2022

# %% [markdown]
# ## **The Data**

# %% [markdown]
# - In Phase 2, as a proof-of-concept, the stakeholder requested a test extraction of movies that started in 2000 or 2001. Each year to be saved as a separate .csv.gz file.
# - In Phase 4, the stakeholder has requested additional years to be extracted.
# - Years 2000-2021 are to be combined into a single TMDB .csv.gz file.

# %% [markdown]
# ## **Import Libraries**

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy.types import *
from sqlalchemy_utils import create_database, database_exists
from sqlalchemy import create_engine

# %% [markdown]
# ## **Import Data**

# %%
# Import TMDB data csv file for the first year
year = 2000
tmdb_results_combined_final_df = pd.read_csv(f'Data/final_tmdb_data_{year}.csv.gz')

# %%
tmdb_results_combined_final_df.head(2)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
#
#         id original_language   original_title  ... revenue  runtime  \
# 0      NaN               NaN              NaN  ...     NaN      NaN
# 1  62127.0                en  The Fantasticks  ...     0.0     86.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                          tagline            title  video  \
# 0                                            NaN              NaN    NaN
# 1  Try to remember the first time magic happened  The Fantasticks    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1           5.4       21.0           NaN
#
# [2 rows x 26 columns]

# %%
# Remove the initial row which has null data
tmdb_results_combined_final_df = tmdb_results_combined_final_df.loc[1:,:]

# %%
# Create a list of years
years = [*range(2001, 2022, 1)]

# %%
# Loop through the years and append each year to the combined dataframe
for year in years:
    # Import TMDB data csv file for the current year
    current_year_df = pd.read_csv(f'Data/final_tmdb_data_{year}.csv.gz')
    # remove the initial row which has null data
    current_year_df = current_year_df.loc[1:,:] 
    # append TMDB data csv file for the current year to the combined dataframe
    tmdb_results_combined_final_df = tmdb_results_combined_final_df.append(current_year_df)

# %%
# Display the head and tail of the dataframe
tmdb_results_combined_final_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 5     tt0118852    0.0                               NaN
# ...         ...    ...                               ...
# 3509  tt9895024    0.0   /S1kutYyoyuBJKGS0mXxv2fZNbr.jpg
# 3510  tt9896876    0.0  /hMvRbT6HOqERhh3K8kXbaLz9LlZ.jpg
# 3511  tt9898844    0.0  /q2KFBGyUSzHDhNqXEYv2LqTWVSz.jpg
# 3512  tt9900940    0.0  /3jjWLg5bevWqReyVroYqxwVrH0k.jpg
# 3513  tt9907782    0.0  /gRTYArznK1MLAq7opC1tYHnTwM3.jpg
#
#      belongs_to_collection      budget  \
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# 5                      NaN         0.0
# ...                    ...         ...
# 3509                   NaN         0.0
# 3510                   NaN         0.0
# 3511                   NaN         0.0
# 3512                   NaN         0.0
# 3513                   NaN         0.0
#
#                                                  genres  \
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2              [{'id': 878, 'name': 'Science Fiction'}]
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5                         [{'id': 18, 'name': 'Drama'}]
# ...                                                 ...
# 3509  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 3510  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3511                     [{'id': 27, 'name': 'Horror'}]
# 3512  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 3513  [{'id': 27, 'name': 'Horror'}, {'id': 14, 'nam...
#
#                                   homepage        id original_language  \
# 1                                      NaN   62127.0                en
# 2                                      NaN  110977.0                en
# 3                                      NaN  442869.0                hi
# 4     http://www.wkw-inthemoodforlove.com/     843.0                cn
# 5                                      NaN   49511.0                en
# ...                                    ...       ...               ...
# 3509                                   NaN  834443.0                de
# 3510                                   NaN  821493.0                en
# 3511                                   NaN  870671.0                en
# 3512                                   NaN  861294.0                en
# 3513                                   NaN  630392.0                en
#
#                original_title  ...     revenue  runtime  \
# 1             The Fantasticks  ...         0.0     86.0
# 2               For the Cause  ...         0.0    100.0
# 3                        Gang  ...         0.0    152.0
# 4                        花樣年華  ...  12854953.0     99.0
# 5              Chinese Coffee  ...         0.0     99.0
# ...                       ...  ...         ...      ...
# 3509              Heikos Welt  ...         0.0    118.0
# 3510  India Sweets and Spices  ...         0.0    101.0
# 3511              The Hunting  ...         0.0     91.0
# 3512             The Scrapper  ...         0.0     87.0
# 3513               The Cursed  ...   4588389.0    111.0
#
#                                        spoken_languages    status  \
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 5     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 3509  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# 3510  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3511  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3512  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3513  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                                 tagline  \
# 1         Try to remember the first time magic happened
# 2          The ultimate showdown on a forbidden planet.
# 3                                                   NaN
# 4     Feel the heat, keep the feeling burning, let t...
# 5     There's a fine line between friendship and bet...
# ...                                                 ...
# 3509                                                NaN
# 3510                              Let the aunties talk.
# 3511                                  Hunger runs deep.
# 3512                        You can't escape your past.
# 3513                                                NaN
#
#                         title  video  vote_average vote_count certification
# 1             The Fantasticks    0.0           5.4       21.0           NaN
# 2               For the Cause    0.0           4.4        7.0           NaN
# 3                        Gang    0.0           0.0        0.0           NaN
# 4        In the Mood for Love    0.0           8.1     1859.0            PG
# 5              Chinese Coffee    0.0           6.9       45.0             R
# ...                       ...    ...           ...        ...           ...
# 3509            Heiko's World    0.0           0.0        0.0           NaN
# 3510  India Sweets and Spices    0.0           6.0        2.0         PG-13
# 3511              The Hunting    0.0           4.9       20.0           NaN
# 3512             The Scrapper    0.0           6.0        2.0           NaN
# 3513               The Cursed    0.0           7.0       55.0             R
#
# [60053 rows x 26 columns]

# %% [markdown]
# ## **TMDB csv file**

# %%
# Save a final merged .csv.gz of all of the TMDB api data 
tmdb_results_combined_final_df.to_csv("Data/tmdb_results_combined_final_df.csv.gz", 
                                compression="gzip", 
                                index=False)

# %% [markdown]
# ## **tmdb_data SQL Table**

# %%
# Drop columns
tmdb_results_combined_final_df = tmdb_results_combined_final_df.loc[:,["imdb_id","revenue",'budget','certification']]

# %%
# Display the first (5) rows
tmdb_results_combined_final_df.head()
# Out:
#      imdb_id     revenue      budget certification
# 1  tt0113026         0.0  10000000.0           NaN
# 2  tt0113092         0.0         0.0           NaN
# 3  tt0116391         0.0         0.0           NaN
# 4  tt0118694  12854953.0    150000.0            PG
# 5  tt0118852         0.0         0.0             R

# %%
# Display the names, non-null values, and datatypes for the columns
tmdb_results_combined_final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60053 entries, 1 to 3513
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   imdb_id        60053 non-null  object
#  1   revenue        60053 non-null  float64
#  2   budget         60053 non-null  float64
#  3   certification  14612 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# #### **Passwords**

# %%
# Obtain the MySQL login username and password
with open('C:/Users/DELL/.secret/mysql_keys.json') as f:
    login = json.load(f)
# Display the MySQL login keys
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %% [markdown]
# #### **Connection**

# %%
# Create a connection string using credentials following this format:
# connection = "dialect+driver://username:password@host:port/database"
database_name = "Movies"
connection_str = f"mysql+pymysql://{login['username']}:{login['password']}@localhost/{database_name}"

# %% [markdown]
# #### **Create the Engine**

# %%
# Create an instance of the sqlalchemy create_engine class
engine = create_engine(connection_str)

# %%
# Calculate max string lengths for object columns
imdb_id_len = tmdb_results_combined_final_df['imdb_id'].fillna('').map(len).max()
certification_len = tmdb_results_combined_final_df['certification'].fillna('').map(len).max()


# Use 1 + the max_str_len for object columns
# Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    'imdb_id': String(imdb_id_len+1), 
    'budget':Float(),
    'revenue':Float(),
    'certification': String(certification_len+1)}

# %%
# Save the dataframe to an sql table
# with appropriate datatypes and set index=False
tmdb_results_combined_final_df.to_sql('tmdb_data',
              engine, 
              dtype=df_schema,
              if_exists='replace',
              index=False)

# %%
# Use the sqlalchemy engine to update the table and set imdb_id as the primary key
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %%
# Display the first 5 rows of the table using an SQL query
q = """
SELECT * 
FROM tmdb_data LIMIT 5
;"""
pd.read_sql(q, engine)
# Out:
#      imdb_id     revenue      budget certification
# 0  tt0035423  76019000.0  48000000.0         PG-13
# 1  tt0062336         0.0         0.0          None
# 2  tt0069049         0.0  12000000.0             R
# 3  tt0088751         0.0    350000.0          None
# 4  tt0093119         0.0   7500000.0          None
